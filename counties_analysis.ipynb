# %%
# Import libraries

import geopandas as gpd
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
or_tracts = gpd.read_file('../Data/or_tract_tiles.shp')

# %%
or_tracts
# Out:
#                 quadkey  avg_d_kbps  avg_u_kbps  avg_lat_ms  tests  devices  \
# 0      0212322030233030       46298        9744           9      4        3
# 1      0212322030231231      113668       24984          19     61       14
# 2      0212322030231213       59392        7597           9     11        4
# 3      0212322030233001      175918      115881          18     44       12
# 4      0212322030230332       61114        9890          10      2        2
# ...                 ...         ...         ...         ...    ...      ...
# 17077  0212213133003330         361         221         332      1        1
# 17078  0212233112220301        1431         472         109      1        1
# 17079  0212213313213013       12649        2029          32      1        1
# 17080  0212302221130113      193202      115061           7     24        6
# 17081  0212302231130302      331206       44155          10     15        4
#
# ...

# %%
# Convert to Mbps
or_tracts['avg_d_mbps'] = or_tracts['avg_d_kbps'] / 1000
or_tracts['avg_u_mbps'] = or_tracts['avg_u_kbps'] / 1000

# %%
or_tracts.head()
# Out:
#             quadkey  avg_d_kbps  avg_u_kbps  avg_lat_ms  tests  devices  \
# 0  0212322030233030       46298        9744           9      4        3
# 1  0212322030231231      113668       24984          19     61       14
# 2  0212322030231213       59392        7597           9     11        4
# 3  0212322030233001      175918      115881          18     44       12
# 4  0212322030230332       61114        9890          10      2        2
#
#    index_righ        GEOID  B28011_001  B28011_002  ...  B28011_006  \
# 0          34  41029000800      2490.0      2229.0  ...        19.0
# 1          34  41029000800      2490.0      2229.0  ...        19.0
# 2          34  41029000800      2490.0      2229.0  ...        19.0
# 3          34  41029000800      2490.0      2229.0  ...        19.0
# 4          34  41029000800      2490.0      2229.0  ...        19.0
#
#    B28011_007  B28011_008                                    NAME  state  \
# ...

# %% [markdown]
# # Rank tracts based on download speed

# %%
median_speeds = or_tracts.groupby('NAME').median()
# Out:
# /var/folders/9_/7w6dl5dd3z718l85r306bpmr0000gn/T/ipykernel_60355/3624930823.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.median is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   median_speeds = or_tracts.groupby('NAME').median()

# %%
median_speeds
# Out:
#                                               avg_d_kbps  avg_u_kbps  \
# NAME
# Census Tract 1, Benton County, Oregon           145327.0      9805.0
# Census Tract 1, Coos County, Oregon              44170.0     10734.5
# Census Tract 1, Deschutes County, Oregon         43723.0      5464.0
# Census Tract 1, Jackson County, Oregon          186496.0     33423.0
# Census Tract 1, Lane County, Oregon              62256.0     10105.0
# ...                                                  ...         ...
# Census Tract 99.06, Multnomah County, Oregon     87723.5     19315.0
# Census Tract 99.07, Multnomah County, Oregon    165113.5     19805.5
# Census Tract 9900, Clatsop County, Oregon          361.0       221.0
# Census Tract 9901, Tillamook County, Oregon      12649.0      2029.0
# Census Tract 9901.01, Curry County, Oregon        1431.0       472.0
#
#                                               avg_lat_ms  tests  devices  \
# NAME
# ...
